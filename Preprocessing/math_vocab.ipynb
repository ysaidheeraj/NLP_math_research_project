# %% [markdown]
# We have existing math vocabulary in MathVocab.xlsx. We are parsing further math vocab from https://en.wikibooks.org/wiki/LaTeX/Mathematics#List_of_mathematical_symbols

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
# URL to get the math tags
url = r"https://en.wikibooks.org/wiki/LaTeX/Mathematics#List_of_mathematical_symbols"

# Sending a GET request and extracting the html content
response = requests.get(url)
html_content = response.content

# %%
# Create BeautifulSoup object from the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find all elements with a specific class
class_name = "k"
class_contents = soup.find_all(class_=class_name)
for content in class_contents:
    print(content.text)
# Out:
# \usepackage
# \usepackage
# \quad
# \lim
# \sum
# \displaystyle
# \everymath
# \displaystyle
# \begin
# \forall
# \in
# \quad
# \exists
# \leq
# \epsilon
# \alpha
# \Alpha
# \beta
# \Beta
# \gamma
# \Gamma
# \pi
# \Pi
# \phi
# \varphi
# \mu
# \Phi
# \cos
# \theta
# \cos
# \theta
# \sin
# \theta
# \lim\limits
# \to
# \infty
# \exp
# \bmod
# \pmod
# \bmod
# \equiv
# \pmod
# \frac
# \binom
# \frac
# \binom
# \frac
# \frac
# \frac
# \tfrac
# \dfrac
# \textstyle
# \displaystyle
# \tbinom
# \dbinom
# \newcommand*\rfrac
# \!
# \rfrac
# \sfrac
# \dots
# \times\sfrac
# \sfrac
# \dots
# \times
# \sfrac
# \nicefrac
# \sfrac
# \cfrac
# \begin
# \cfrac
# \cfrac
# \cfrac
# \cfrac
# \end
# \begin
# \frac
# \begin
# \left
# \right
# \\
# \times
# \left
# \right
# \end
# \left
# \right
# \end
# \sqrt
# \sqrt
# \frac
# \sqrt
# \dots
# \let\oldsqrt\sqrt
# \def\sqrt
# \mathpalette\DHLhksqrt
# \def\DHLhksqrt
# \setbox
# \hbox
# \dimen
# \ht
# \advance\dimen
# \ht
# \setbox
# \hbox
# \vrule
# \ht
# ...
